# %% [markdown]
# # Inventario Ferretería EdoMex

# %%
import numpy as np
import pandas as pd
import statistics
import matplotlib.pyplot as plt

# %%
inventario = pd.read_csv("datax/inventario_ferreteria_edomex.csv")
inventario
# Out:
#   ubicacion            tipo de producto descripcion del producto  cantidad  \
# 0    Toluca                herramientas            llave inglesa        40
# 1    Toluca                electricidad           enchufe triple        75
# 2   Metepec                herramientas                  alicate        15
# 3   Metepec  materiales de construcción       bloque de concreto       200
# 4    Toluca                    plomería              tubo de PVC       100
# 5   Metepec                    plomería            codo de cobre        50
# 6    Toluca                electricidad       interruptor de luz        80
# 7   Metepec  materiales de construcción          saco de cemento        30
# 8    Toluca                herramientas         serrucho de mano        60
# 9   Metepec                herramientas           destornillador        90
#
#    precio
# 0   120.0
# 1    30.0
# 2   250.0
# 3    12.0
# 4    45.0
# 5    25.0
# 6    55.0
# 7   140.0
# 8    80.0
# 9    35.0

# %%
# Obtenemos la frecuencia de la columna 'tipo de producto'
frecuencia_tipo_de_producto = inventario['tipo de producto'].value_counts()

print(frecuencia_tipo_de_producto)
# Out:
# herramientas                  4
# electricidad                  2
# materiales de construcción    2
# plomería                      2
# Name: tipo de producto, dtype: int64

# %%
frecuencia_tipo_de_producto.plot(kind='bar', color='skyblue')
plt.title('Frecuencia de tipo de producto')
plt.xlabel('Tipo de producto')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Graficamos un gráfico de pastel mostrando los porcentajes
plt.pie(frecuencia_tipo_de_producto, labels=frecuencia_tipo_de_producto.index, 
        autopct='%1.1f%%', colors=['red', 'blue', 'green', "yellow"])
plt.title('Distribución de tipos de producto')
plt.show()

# %%
precios = inventario["precio"]
# Media
media_precios = np.mean(precios)
# Mediana
mediana_precios = np.median(precios)
print(f"media_precios: {media_precios}")
print(f"mediana_precios: {mediana_precios}")
# Out:
# media_precios: 79.2
# mediana_precios: 50.0

# %%
precios.sort_values()
# Out:
# 3     12.0
# 5     25.0
# 1     30.0
# 9     35.0
# 4     45.0
# 6     55.0
# 8     80.0
# 0    120.0
# 7    140.0
# 2    250.0
# Name: precio, dtype: float64

# %%
cantidades = inventario["cantidad"]
# Media
media_cantidades = np.mean(cantidades)
# Calculamos la desviación estándar
desviacion_estandar_cantidades = statistics.stdev(cantidades)
print(f"media_cantidades: {media_cantidades}")
print(f"desviacion_estandar_cantidades: {desviacion_estandar_cantidades:.2f}")
# Out:
# media_cantidades: 74.0
# desviacion_estandar_cantidades: 51.84

# %%
# Definir los límites de clase
bins = [1, 51, 101, 151, 201, 251]
# Usamos pd.cut() para segmentar los datos en los intervalos
precios_binned = pd.cut(precios, bins)

# Creamos la tabla de distribución de frecuencias usando value_counts()
tabla_frecuencia = precios_binned.value_counts()

print(tabla_frecuencia.sort_index())
# Out:
# (1, 51]       5
# (51, 101]     2
# (101, 151]    2
# (151, 201]    0
# (201, 251]    1
# Name: precio, dtype: int64

# %%
# Crear el histograma
# Graficamos el histograma
tabla_frecuencia.sort_index().plot(kind='bar', color='lightblue', edgecolor='black')


# Añadir etiquetas y título
plt.title('Histograma de Frecuencias')
plt.xlabel('Clases')
plt.ylabel('Frecuencia')

# Mostrar el gráfico
plt.show()

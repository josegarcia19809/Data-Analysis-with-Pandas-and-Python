# %%
import pandas as pd

# %%
inventario = pd.read_csv("datax/inventario_edo_mex.csv")
inventario
# Out:
#    ubicacion        tipo de producto              descripcion del producto  \
# 0  Naucalpan                semillas                             herbicida
# 1  Naucalpan                macetero                           insecticida
# 2  Naucalpan       control de plagas                                paleta
# 3   Ecatepec                macetero                            carretilla
# 4  Naucalpan  herramientas de jardin                                tomate
# 5   Ecatepec  herramientas de jardin                             rastrillo
# 6  Naucalpan       control de plagas                             margarita
# 7   Ecatepec       control de plagas    macetero de plastico de 8 pulgadas
# 8   Ecatepec                semillas                                  cala
# 9  Naucalpan                macetero  macetero de terracota de 20 pulgadas
#
#    cantidad  precio
# 0        74    23.0
# 1        48    36.0
# 2        56    36.0
# 3        73    23.0
# 4         0    56.0
# ...

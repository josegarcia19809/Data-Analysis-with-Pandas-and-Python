# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Crear un rango de valores para x
x = np.linspace(0, 6, 13)  # Ajusta el rango según sea necesario

# Calcular los valores de y
y = -2 * x ** 2 + 12 * x - 15

# %%
# Imprimir valores
for xi, yi in zip(x, y):
    print(f"x: {xi:.2f}, f(x): {yi:.2f}")
# Out:
# x: 0.00, f(x): -15.00
# x: 0.50, f(x): -9.50
# x: 1.00, f(x): -5.00
# x: 1.50, f(x): -1.50
# x: 2.00, f(x): 1.00
# x: 2.50, f(x): 2.50
# x: 3.00, f(x): 3.00
# x: 3.50, f(x): 2.50
# x: 4.00, f(x): 1.00
# x: 4.50, f(x): -1.50
# x: 5.00, f(x): -5.00
# x: 5.50, f(x): -9.50
# x: 6.00, f(x): -15.00

# %%
# Crear las gráficas
plt.figure(figsize=(12, 6))

# Graficar la función de ganancia
plt.plot(x, y, label='Ganancia: $-2x^2 + 12x - 15$', color='blue')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.scatter([3], [3], color='red', zorder=5)  # Mostrar el máximo en rojo
plt.title('Función de Ganancia')
plt.xlabel('Número de Unidades Vendidas (x)')
plt.ylabel('Ganancia (G(x))')
plt.legend()

# Ajustar la visualización
plt.tight_layout()
plt.show()
